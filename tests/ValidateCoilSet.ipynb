# %%
import sys
sys.path.append("..")
import numpy as np
import focusadd
from focusadd.surface.Surface import Surface
from focusadd.coils.CoilSet import CoilSet
import numpy as np
import mayavi as maya
from mayavi import mlab
mlab.init_notebook()
# Out:
# Notebook initialized with x3d backend.

# %% [markdown]
# # Validate CoilSet.Py
#
# # Test 1: Coil Initialization
#
# Let's test the coil initialization. There are two ways of initializing coils, either from a preformatted args_dict dictionary or from an existing .hdf5 file which stores the coil data and metadata. Let's make sure we can do this successfully.

# %% [markdown]
# Let's start by looking at a basic circular axis and circular cross section, and making sure we can properly initialize the coils around this axis. Then we'll make sure we can write these to an .hdf5 file, then read them in again.

# %%
mlab.clf()
surface = Surface("../focusadd/initFiles/axes/circularAxis.txt", 64, 32, 1.0)
r = surface.get_r()
x = r[:,:,0]
y = r[:,:,1]
z = r[:,:,2]
s = mlab.mesh(x,y,z,color=(0.8,0.0,0.0))
args_dict = {}
args_dict['numCoils'] = 8
args_dict['numSegments'] = 32
args_dict['numFourierCoils'] = 4
args_dict['numFourierRotate'] = 4
args_dict['lengthNormal'] = 0.02
args_dict['lengthBinormal'] = 0.02
args_dict['numNormalRotate'] = 2
args_dict['numBinormalRotate'] = 2
args_dict['radiusCoil'] = 2.0
args_dict['numRotate'] = 0
coilSet = CoilSet(surface,args_dict = args_dict)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/jax/lib/xla_bridge.py:119: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
r_coils = coilSet.get_r()
for ic in range(r_coils.shape[0]):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))

# %%
p
# Out:
#     <?xml version="1.0" encoding ="UTF-8"?>
#
# <X3D profile="Immersive" version="3.0" id="scene_0" >
#   <head>
#     <meta name="filename" content="Stream"/>
#     <meta name="generator" content="Visualization ToolKit X3D exporter v0.9.1"/>
#     <meta name="numberofelements" content="33"/>
#   </head>
#   <Scene>
#     <Background skyColor="0.5 0.5 0.5"/>
#     <Viewpoint fieldOfView="0.523599" position="3.85944 3.85944 3.85944" description="Default View" orientation="0.187053 0.451587 0.872399 -3.83511" centerOfRotation="0 0 0"/>
#     <NavigationInfo type='"EXAMINE" "FLY" "ANY"' speed="4" headlight="true"/>
#     <DirectionalLight ambientIntensity="1" intensity="0" color="1 1 1"/>
#     <Transform DEF="ROOT" translation="0 0 0">
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="true"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 0 -1" color="1 1 1" intensity="1" on="false"/>
#       <Transform translation="0 0 0" rotation="0 0 1 -0" scale="1 1 1">
#         <Shape>
#           <Appearance>
#             <Material ambientIntensity="0" emissiveColor="0 0 0" diffuseColor="0.8 0 0" specularColor="0 0 0" shininess="0.0078125" transparency="0"/>
#           </Appearance>
#             134 167 168 -1
#             135 168 169 -1
#             136 169 170 -1
#             137 170 171 -1
#             138 171 172 -1
#             139 172 173 -1
#             140 173 174 -1
#             141 174 175 -1
#             142 175 176 -1
#             143 176 177 -1
#             144 177 178 -1
#             145 178 179 -1
#             146 179 180 -1
#             147 180 181 -1
#             148 181 182 -1
#             149 182 183 -1
#             150 183 184 -1
#             151 184 185 -1
#             152 185 186 -1
#             153 186 187 -1
#             154 187 188 -1
#             155 188 189 -1
#             156 189 190 -1
#             157 190 191 -1
#             158 191 192 -1
#             159 192 193 -1
#             160 193 194 -1
#             161 194 195 -1
#             162 195 196 -1
#             163 196 197 -1
#             165 198 199 -1
#             166 199 200 -1
#             167 200 201 -1
#             168 201 202 -1
#             169 202 203 -1
#             170 203 204 -1
#             171 204 205 -1
#             172 205 206 -1
#             173 206 207 -1
#             174 207 208 -1
#             175 208 209 -1
#             176 209 210 -1
#             177 210 211 -1
#             178 211 212 -1
#             179 212 213 -1
#             180 213 214 -1
#             181 214 215 -1
#             182 215 216 -1
#             183 216 217 -1
#             184 217 218 -1
#             185 218 219 -1
#             186 219 220 -1
#             187 220 221 -1
#             188 221 222 -1
#             189 222 223 -1
#             190 223 224 -1
#             191 224 225 -1
#             192 225 226 -1
#             193 226 227 -1
#             194 227 228 -1
#             195 228 229 -1
#             196 229 230 -1
#             198 231 232 -1
#             199 232 233 -1
#             200 233 234 -1
#             201 234 235 -1
#             202 235 236 -1
#             203 236 237 -1
#             204 237 238 -1
#             205 238 239 -1
#             206 239 240 -1
#             207 240 241 -1
#             208 241 242 -1
#             209 242 243 -1
#             210 243 244 -1
#             211 244 245 -1
#             212 245 246 -1
#             213 246 247 -1
#             214 247 248 -1
#             215 248 249 -1
#             216 249 250 -1
#             217 250 251 -1
#             218 251 252 -1
#             219 252 253 -1
#             220 253 254 -1
#             221 254 255 -1
#             222 255 256 -1
#             223 256 257 -1
#             224 257 258 -1
#             225 258 259 -1
#             226 259 260 -1
#             227 260 261 -1
#             228 261 262 -1
#             229 262 263 -1
#             231 264 265 -1
#             232 265 266 -1
#             233 266 267 -1
#             234 267 268 -1
#             235 268 269 -1
#             236 269 270 -1
#             237 270 271 -1
#             238 271 272 -1
#             239 272 273 -1
#             240 273 274 -1
#             241 274 275 -1
#             242 275 276 -1
#             243 276 277 -1
#             244 277 278 -1
#             245 278 279 -1
#             246 279 280 -1
#             247 280 281 -1
#             248

# %% [markdown]
# It should work for any number of coils.

# %%
mlab.clf()
p = mlab.mesh(x,y,z,color=(0.8,0.0,0.0))
args_dict['numCoils'] = 13
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(r_coils.shape[0]):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))

# %%
p

# %% [markdown]
# 13 coils, evenly spaced. Great.
#
# The next step is to store this as an hdf5 file, then read it back in and get the same coils. Let's do that and make sure it works.

# %%
coilSet.write("13coilsTest.hdf5")

# %%
coilSet13 = CoilSet(surface,input_file="13coilsTest.hdf5")

# %%
mlab.clf()
p = mlab.mesh(x,y,z,color=(0.8,0.0,0.0))
r_coils = coilSet13.get_r()
for ic in range(r_coils.shape[0]):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))

# %%
p

# %% [markdown]
# coilSet13 looks good. So writing and reading from hdf5 files gives us the same coils.
#
# Now let's see if we properly initialize our coils around an elliptical axis.

# %%
mlab.clf()
surface = Surface("../focusadd/initFiles/axes/ellipticalAxis5Rotate.txt", 64, 32, 1.0)
r = surface.get_r()
x = r[:,:,0]
y = r[:,:,1]
z = r[:,:,2]
p = mlab.mesh(x,y,z,color=(0.8,0.0,0.0))
args_dict = {}
args_dict['numCoils'] = 8
args_dict['numSegments'] = 32
args_dict['numFourierCoils'] = 4
args_dict['numFourierRotate'] = 4
args_dict['lengthNormal'] = 0.02
args_dict['lengthBinormal'] = 0.02
args_dict['numNormalRotate'] = 2
args_dict['numBinormalRotate'] = 2
args_dict['radiusCoil'] = 2.0
args_dict['numRotate'] = 0
coilSet = CoilSet(surface,args_dict = args_dict)

# %%
r_coils = coilSet.get_r()
for ic in range(r_coils.shape[0]):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))

# %%
p

# %% [markdown]
# # Test 2: Frenet Frame
#
# Let's look at the tangent, normal, and binormal vectors for coils initialized around an elliptical surface. Hopefully they match our expectations, a more thorough debugging might be challenging.
#
# For ease of viewing, I only plotted the central coil filament.

# %%
surface = Surface("../focusadd/initFiles/axes/ellipticalAxis5Rotate.txt", 64, 32, 1.0)
r = surface.get_r()
x = r[:,:,0]
y = r[:,:,1]
z = r[:,:,2]
args_dict = {}
args_dict['numCoils'] = 8
args_dict['numSegments'] = 32
args_dict['numFourierCoils'] = 4
args_dict['numFourierRotate'] = 4
args_dict['lengthNormal'] = 0.02
args_dict['lengthBinormal'] = 0.02
args_dict['numNormalRotate'] = 2
args_dict['numBinormalRotate'] = 2
args_dict['radiusCoil'] = 2.0
args_dict['numRotate'] = 0
coilSet = CoilSet(surface,args_dict = args_dict)

# %%
mlab.clf()
r_coils = coilSet.get_r()
r_central = coilSet.get_r_central()
T = coilSet.get_tangent()
N = coilSet.get_normal()
B = coilSet.get_binormal()
p = mlab.mesh(x,y,z,color=(0.8,0.0,0.0))
for ic in range(r_coils.shape[0]):
    p = mlab.quiver3d(r_central[::,::,0],r_central[::,::,1],r_central[::,::,2],T[::,::,0],T[::,::,1],T[::,::,2])
    p = mlab.plot3d(r_central[ic,:,0],r_central[ic,:,1],r_central[ic,:,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))

# %%
p

# %%
mlab.clf()
r_coils = coilSet.get_r()
r_central = coilSet.get_r_central()
T = coilSet.get_tangent()
N = coilSet.get_normal()
B = coilSet.get_binormal()
for ic in range(r_coils.shape[0]):
    p = mlab.quiver3d(r_central[::,::,0],r_central[::,::,1],r_central[::,::,2],N[::,::,0],N[::,::,1],N[::,::,2],color=(0.8,0.0,0.0))
    p = mlab.plot3d(r_central[ic,:,0],r_central[ic,:,1],r_central[ic,:,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))

# %%
p

# %%
mlab.clf()
r_coils = coilSet.get_r()
r_central = coilSet.get_r_central()
T = coilSet.get_tangent()
N = coilSet.get_normal()
B = coilSet.get_binormal()
#p = mlab.mesh(x,y,z,color=(0.8,0.0,0.0))
for ic in range(r_coils.shape[0]):
    p = mlab.quiver3d(r_central[::,::,0],r_central[::,::,1],r_central[::,::,2],B[::,::,0],B[::,::,1],B[::,::,2],color=(0.8,0.0,0.0))
    p = mlab.plot3d(r_central[ic,:,0],r_central[ic,:,1],r_central[ic,:,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))

# %%
p

# %% [markdown]
# Seems right.

# %% [markdown]
# # Test 3: Multi-filament parametrization

# %% [markdown]
# Let's make sure our winding pack approximation to the finite-build coils is doing what we want it to be doing. Let's start by varying arg_dict and seeing how that changes the properties of our multi-filament coils.
#
# Let's vary:
#
# 1. numFourierCoils (NF)
# 2. numFourierRotate (NFR)
# 3. lengthNormal (ln or l1)
# 4. lengthBinormal (lb or l2)
# 5. radiusCoil
# 6. numNormalRotate (NNR)
# 7. numBinormalRotate (NBR)
# 8. numRotate
# 9. Fourier series of rotation
#
# Here are our default settings.

# %%
mlab.clf()
surface = Surface("../focusadd/initFiles/axes/ellipticalAxis5Rotate.txt", 64, 32, 1.0)
r = surface.get_r()
x = r[:,:,0]
y = r[:,:,1]
z = r[:,:,2]
#p = mlab.mesh(x,y,z,color=(0.8,0.0,0.0))
args_dict = {}
args_dict['numCoils'] = 8
args_dict['numSegments'] = 32
args_dict['numFourierCoils'] = 4
args_dict['numFourierRotate'] = 4
args_dict['lengthNormal'] = 0.02
args_dict['lengthBinormal'] = 0.02
args_dict['numNormalRotate'] = 2
args_dict['numBinormalRotate'] = 2
args_dict['radiusCoil'] = 2.0
args_dict['numRotate'] = 0
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p
# Out:
#     <?xml version="1.0" encoding ="UTF-8"?>
#
# <X3D profile="Immersive" version="3.0" id="scene_1" >
#   <head>
#     <meta name="filename" content="Stream"/>
#     <meta name="generator" content="Visualization ToolKit X3D exporter v0.9.1"/>
#     <meta name="numberofelements" content="4"/>
#   </head>
#   <Scene>
#     <Background skyColor="0.5 0.5 0.5"/>
#     <Viewpoint fieldOfView="0.523599" position="1.94331 0.765765 0.765765" description="Default View" orientation="0.187053 0.451587 0.872399 -3.83511" centerOfRotation="1.17754 0 0"/>
#     <NavigationInfo type='"EXAMINE" "FLY" "ANY"' speed="4" headlight="true"/>
#     <DirectionalLight ambientIntensity="1" intensity="0" color="1 1 1"/>
#     <Transform DEF="ROOT" translation="0 0 0">
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="true"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 0 -1" color="1 1 1" intensity="1" on="false"/>
#       <Transform translation="0 0 0" rotation="0 0 1 -0" scale="1 1 1">
#         <Shape>
#           <Appearance>
#             <Material ambientIntensity="0" emissiveColor="0 0 0" diffuseColor="0 0 0.8" specularColor="0 0 0" shininess="0.0078125" transparency="0"/>
#           </Appearance>
#           <IndexedFaceSet solid="false" colorPerVertex="false" normalPerVertex="true" coordIndex="
#             1 0 7 -1
#             7 0 6 -1
#             7 6 13 -1
#             13 6 12 -1
#             13 12 19 -1
#             19 12 18 -1
#             19 18 25 -1
#             25 18 24 -1
#             25 24 31 -1
#             31 24 30 -1
#             31 30 37 -1
#             37 30 36 -1
#             37 36 43 -1
#             43 36 42 -1
#             43 42 49 -1
#             49 42 48 -1
#             49 48 55 -1
#             55 48 54 -1
#             55 54 61 -1
#             61 54 60 -1
#             61 60 67 -1
#             67 60 66 -1
#             67 66 73 -1
#             73 66 72 -1
#             73 72 79 -1
#             79 72 78 -1
#             79 78 85 -1
#             85 78 84 -1
#             85 84 91 -1
#             91 84 90 -1
#             91 90 97 -1
#             97 90 96 -1
#             97 96 103 -1
#             103 96 102 -1
#             103 102 109 -1
#             109 102 108 -1
#             109 108 115 -1
#             115 108 114 -1
#             115 114 121 -1
#             121 114 120 -1
#             121 120 127 -1
#             127 120 126 -1
#             127 126 133 -1
#             133 126 132 -1
#             133 132 139 -1
#             139 132 138 -1
#             139 138 145 -1
#             145 138 144 -1
#             145 144 151 -1
#             151 144 150 -1
#             151 150 157 -1
#             157 150 156 -1
#             157 156 163 -1
#             163 156 162 -1
#             163 162 169 -1
#             169 162 168 -1
#             169 168 175 -1
#             175 168 174 -1
#             175 174 181 -1
#             181 174 180 -1
#             181 180 187 -1
#             187 180 186 -1
#             187 186 193 -1
#             193 186 192 -1
#             2 1 8 -1
#             8 1 7 -1
#             8 7 14 -1
#             14 7 13 -1
#             14 13 20 -1
#             20 13 19 -1
#             20 19 26 -1
#             26 19 25 -1
#             26 25 32 -1
#             32 25 31 -1
#             32 31 38 -1
#             38 31 37 -1
#             38 37 44 -1
#             44 37 43 -1
#             44 43 50 -1
#             50 43 49 -1
#             50 49 56 -1
#             56 49 55 -1
#             56 55 62 -1
#             62 55 61 -1
#             62 61 68 -1
#             68 61 67 -1
#             68 67 74 -1
#             74 67 73 -1
#             74 73 80 -1
#             80 73 79 -1
#             80 79 86 -1
#             86 79 85 -1
#             86 85 92 -1
#             92 85 91 -1
#             92 91 98 -1
#             98 91 97 -1
#             98 97 104 -1
#             104 97 103 -1
#             104 103 110 -1
#             110 103 109 -1
#             110 109 116 -1
#             116 109 115 -1
#             116 115 122 -1
#             122 115 121 -1
#             122 121 128 -1
#             128 121 127 -1
#             128 127 134 -1
#             134 127 133 -1
#             134 133 140 -1
#             140 133 139 -1
#             140 139 146 -1
#             146 139 145 -1
#             146 145 152 -1
#             152 145 151 -1
#             152 151 158 -1
#             158 151 157 -1
#             158 157 164 -1

    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
mlab.clf()
args_dict['numFourierCoils'] = 3
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['numFourierCoils'] = 4

# %% [markdown]
# 2. numFourierRotate (NFR)

# %%
mlab.clf()
args_dict['numFourierRotate'] = 1
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
mlab.clf()
args_dict['numFourierRotate'] = 0
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['numFourierRotate'] = 4

# %% [markdown]
# 3. lengthNormal (ln or l1)

# %%
mlab.clf()
args_dict['lengthNormal'] = 0.04
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
mlab.clf()
args_dict['lengthNormal'] = 0.08
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['lengthNormal'] = 0.02

# %% [markdown]
# 4. lengthBinormal (lb or l2)

# %%
mlab.clf()
args_dict['lengthBinormal'] = 0.08
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['lengthBinormal'] = 0.02

# %% [markdown]
# 5. radiusCoil

# %%
mlab.clf()
args_dict['radiusCoil'] = 4.0
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
mlab.clf()
args_dict['radiusCoil'] = 8.0
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['radiusCoil'] = 2.0

# %% [markdown]
# 6. numNormalRotate (NNR)

# %%
mlab.clf()
args_dict['numNormalRotate'] = 4
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['numNormalRotate'] = 2

# %% [markdown]
# 7. numBinormalRotate (NBR)

# %%
mlab.clf()
args_dict['numBinormalRotate'] = 4
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['numBinormalRotate'] = 2

# %% [markdown]
# 8. numRotate

# %%
mlab.clf()
args_dict['numRotate'] = 1
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
mlab.clf()
args_dict['numRotate'] = 2
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
mlab.clf()
args_dict['numRotate'] = 3
coilSet = CoilSet(surface,args_dict = args_dict)
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p

# %%
args_dict['numRotate'] = 0

# %% [markdown]
# 9. Fourier series of rotation

# %%
fc, fr = coilSet.get_params()

# %%
print(fr.shape)
# Out:
# (2, 8, 4)

# %%
from jax.ops import index, index_update
fr = index_update(fr, index[0,0,0],3.14/4.)
coilSet.set_params((fc,fr))

# %%
mlab.clf()
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p
# Out:
#     <?xml version="1.0" encoding ="UTF-8"?>
#
# <X3D profile="Immersive" version="3.0" id="scene_2" >
#   <head>
#     <meta name="filename" content="Stream"/>
#     <meta name="generator" content="Visualization ToolKit X3D exporter v0.9.1"/>
#     <meta name="numberofelements" content="4"/>
#   </head>
#   <Scene>
#     <Background skyColor="0.5 0.5 0.5"/>
#     <Viewpoint fieldOfView="0.523599" position="1.9451 0.767551 0.767556" description="Default View" orientation="0.187053 0.451587 0.872399 -3.83511" centerOfRotation="1.17754 -2.58535e-06 2.5779e-06"/>
#     <NavigationInfo type='"EXAMINE" "FLY" "ANY"' speed="4" headlight="true"/>
#     <DirectionalLight ambientIntensity="1" intensity="0" color="1 1 1"/>
#     <Transform DEF="ROOT" translation="0 0 0">
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="true"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 0 -1" color="1 1 1" intensity="1" on="false"/>
#       <Transform translation="0 0 0" rotation="0 0 1 -0" scale="1 1 1">
#         <Shape>
#           <Appearance>
#             <Material ambientIntensity="0" emissiveColor="0 0 0" diffuseColor="0 0 0.8" specularColor="0 0 0" shininess="0.0078125" transparency="0"/>
#           </Appearance>
#           <IndexedFaceSet solid="false" colorPerVertex="false" normalPerVertex="true" coordIndex="
#             1 0 7 -1
#             7 0 6 -1
#             7 6 13 -1
#             13 6 12 -1
#             13 12 19 -1
#             19 12 18 -1
#             19 18 25 -1
#             25 18 24 -1
#             25 24 31 -1
#             31 24 30 -1
#             31 30 37 -1
#             37 30 36 -1
#             37 36 43 -1
#             43 36 42 -1
#             43 42 49 -1
#             49 42 48 -1
#             49 48 55 -1
#             55 48 54 -1
#             55 54 61 -1
#             61 54 60 -1
#             61 60 67 -1
#             67 60 66 -1
#             67 66 73 -1
#             73 66 72 -1
#             73 72 79 -1
#             79 72 78 -1
#             79 78 85 -1
#             85 78 84 -1
#             85 84 91 -1
#             91 84 90 -1
#             91 90 97 -1
#             97 90 96 -1
#             97 96 103 -1
#             103 96 102 -1
#             103 102 109 -1
#             109 102 108 -1
#             109 108 115 -1
#             115 108 114 -1
#             115 114 121 -1
#             121 114 120 -1
#             121 120 127 -1
#             127 120 126 -1
#             127 126 133 -1
#             133 126 132 -1
#             133 132 139 -1
#             139 132 138 -1
#             139 138 145 -1
#             145 138 144 -1
#             171 164 170 -1
#             171 170 177 -1
#             177 170 176 -1
#             177 176 183 -1
#             183 176 182 -1
#             183 182 189 -1
#             189 182 188 -1
#             189 188 195 -1
#             195 188 194 -1
#             4 3 10 -1
#             10 3 9 -1
#             10 9 16 -1
#             16 9 15 -1
#             16 15 22 -1
#             22 15 21 -1
#             22 21 28 -1
#             28 21 27 -1
#             28 27 34 -1
#             34 27 33 -1
#             34 33 40 -1
#             40 33 39 -1
#             40 39 46 -1
#             46 39 45 -1
#             46 45 52 -1
#             52 45 51 -1
#             52 51 58 -1
#             58 51 57 -1
#             58 57 64 -1
#             64 57 63 -1
#             64 63 70 -1
#             70 63 69 -1
#             70 69 76 -1
#             76 69 75 -1
#             76 75 82 -1
#             82 75 81 -1
#             82 81 88 -1
#             88 81 87 -1
#             88 87 94 -1
#             94 87 93 -1
#             94 93 100 -1
#             100 93 99 -1
#             100 99 106 -1
#             106 99 105 -1
#             106 105 112 -1
#             112 105 111 -1
#             112 111 118 -1
#             118 111 117 -1
#             118 117 124 -1
#             124 117 123 -1
#             124 123 130 -1
#             130 123 129 -1
#             130 129 136 -1
#             136 129 135 -1
#             136 135 142 -1
#             142 135 141 -1
#             142 141 148 -1
#             148 141 147 -1
#             148 147 154 -1
#             154 147 153 -1
#             154 153 160 -1
#             160 153 159 -1
#             160 159 166 -1
#             166 159 165 -1
#             166 165 172 -1

# %%
fr = index_update(fr, index[0,0,0],0.0)
fr = index_update(fr, index[0,0,1],3.14/2)
coilSet.set_params((fc,fr))

# %%
mlab.clf()
r_coils = coilSet.get_r()
for ic in range(1):
    for n in range(r_coils.shape[2]):
        for b in range(r_coils.shape[3]):
            p = mlab.plot3d(r_coils[ic,:,n,b,0],r_coils[ic,:,n,b,1],r_coils[ic,:,n,b,2],tube_radius=0.004, line_width = 0.01, color=(0.0,0.0,0.8))
p
# Out:
#     <?xml version="1.0" encoding ="UTF-8"?>
#
# <X3D profile="Immersive" version="3.0" id="scene_3" >
#   <head>
#     <meta name="filename" content="Stream"/>
#     <meta name="generator" content="Visualization ToolKit X3D exporter v0.9.1"/>
#     <meta name="numberofelements" content="4"/>
#   </head>
#   <Scene>
#     <Background skyColor="0.5 0.5 0.5"/>
#     <Viewpoint fieldOfView="0.523599" position="1.94334 0.765833 0.765736" description="Default View" orientation="0.187053 0.451587 0.872399 -3.83511" centerOfRotation="1.17755 3.7998e-05 -5.90086e-05"/>
#     <NavigationInfo type='"EXAMINE" "FLY" "ANY"' speed="4" headlight="true"/>
#     <DirectionalLight ambientIntensity="1" intensity="0" color="1 1 1"/>
#     <Transform DEF="ROOT" translation="0 0 0">
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="true"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="false"/>
#       <DirectionalLight direction="0 0 -1" color="1 1 1" intensity="1" on="false"/>
#       <Transform translation="0 0 0" rotation="0 0 1 -0" scale="1 1 1">
#         <Shape>
#           <Appearance>
#             <Material ambientIntensity="0" emissiveColor="0 0 0" diffuseColor="0 0 0.8" specularColor="0 0 0" shininess="0.0078125" transparency="0"/>
#           </Appearance>
#           <IndexedFaceSet solid="false" colorPerVertex="false" normalPerVertex="true" coordIndex="
#             1 0 7 -1
#             7 0 6 -1
#             7 6 13 -1
#             13 6 12 -1
#             13 12 19 -1
#             19 12 18 -1
#             19 18 25 -1
#             25 18 24 -1
#             25 24 31 -1
#             31 24 30 -1
#             31 30 37 -1
#             37 30 36 -1
#             37 36 43 -1
#             43 36 42 -1
#             43 42 49 -1
#             49 42 48 -1
#             49 48 55 -1
#             55 48 54 -1
#             55 54 61 -1
#             61 54 60 -1
#             61 60 67 -1
#             67 60 66 -1
#             67 66 73 -1
#             73 66 72 -1
#             73 72 79 -1
#             79 72 78 -1
#             79 78 85 -1
#             85 78 84 -1
#             85 84 91 -1
#             91 84 90 -1
#             91 90 97 -1
#             97 90 96 -1
#             97 96 103 -1
#             103 96 102 -1
#             103 102 109 -1
#             109 102 108 -1
#             109 108 115 -1
#             115 108 114 -1
#             115 114 121 -1
#             121 114 120 -1
#             121 120 127 -1
#             127 120 126 -1
#             127 126 133 -1
#             133 126 132 -1
#             133 132 139 -1
#             139 132 138 -1
#             139 138 145 -1
#             145 138 144 -1
#             145 144 151 -1
#             151 144 150 -1
#             151 150 157 -1
#             157 150 156 -1
#             157 156 163 -1
#             163 156 162 -1
#             163 162 169 -1
#             169 162 168 -1
#             169 168 175 -1
#             175 168 174 -1
#             175 174 181 -1
#             181 174 180 -1
#             181 180 187 -1
#             187 180 186 -1
#             187 186 193 -1
#             193 186 192 -1
#             2 1 8 -1
#             8 1 7 -1
#             8 7 14 -1
#             14 7 13 -1
#             14 13 20 -1
#             20 13 19 -1
#             20 19 26 -1
#             26 19 25 -1
#             26 25 32 -1
#             32 25 31 -1
#             32 31 38 -1
#             38 31 37 -1
#             38 37 44 -1
#             44 37 43 -1
#             44 43 50 -1
#             50 43 49 -1
#             50 49 56 -1
#             56 49 55 -1
#             56 55 62 -1
#             62 55 61 -1
#             62 61 68 -1
#             68 61 67 -1
#             68 67 74 -1
#             74 67 73 -1
#             74 73 80 -1
#             80 73 79 -1
#             80 79 86 -1
#             86 79 85 -1
#             86 85 92 -1
#             92 85 91 -1
#             92 91 98 -1
#             98 91 97 -1
#             98 97 104 -1
#             104 97 103 -1
#             104 103 110 -1
#             110 103 109 -1
#             110 109 116 -1
#             116 109 115 -1
#             116 115 122 -1
#             122 115 121 -1
#             122 121 128 -1
#             128 121 127 -1
#             128 127 134 -1
#             134 127 133 -1
#             134 133 140 -1
#             140 133 139 -1
#             140 139 146 -1
#             146 139 145 -1
#             146 145 152 -1
#             152 145 151 -1
